# %%
# notes:

# we did changes in the model as well so plz undo those changes as well if they dont work

# %% [markdown]
# # **Data Collection**

# %%
# !wget -q https://git.io/J0fjL -O IAM_Words.zip

# !unzip -qq IAM_Words.zip

# !mkdir data 
# !mkdir data/words
# !tar -xf IAM_Words/words.tgz -C data/words
# !mv IAM_Words/words.txt data
# Out:
# mkdir: cannot create directory ‘data’: File exists
# mkdir: cannot create directory ‘data/words’: File exists

# %%
# !head -20 data/words.txt
# Out:
# #--- words.txt ---------------------------------------------------------------#
# #
# # iam database word information
# #
# # format: a01-000u-00-00 ok 154 1 408 768 27 51 AT A
# #
# #     a01-000u-00-00  -> word id for line 00 in form a01-000u
# #     ok              -> result of word segmentation
# #                            ok: word was correctly
# #                            er: segmentation of word can be bad
# #
# #     154             -> graylevel to binarize the line containing this word
# #     1               -> number of components for this word
# #     408 768 27 51   -> bounding box around this word in x,y,w,h format
# #     AT              -> the grammatical tag for this word, see the
# #                        file tagset.txt for an explanation
# #     A               -> the transcription for this word
# #
# a01-000u-00-00 ok 154 408 768 27 51 AT A
# a01-000u-00-01 ok 154 507 766 213 48 NN MOVE

# %%
from tensorflow.keras.layers.experimental.preprocessing import StringLookup
from tensorflow import keras
import matplotlib.pyplot as plt
import tensorflow as tf

import numpy as np
import os

np.random.seed(42)
tf.random.set_seed(42)
# Out:
# 2024-06-29 11:08:05.345666: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # **Dataset Splitting**

# %%
base_path = "./data"
words_list = []

words = open(f"{base_path}/words.txt", "r").readlines()
for line in words:
  if line[0] =="#":
    continue
  if line.split(" ")[1] != "err":
    words_list.append(line)

len(words_list)

np.random.shuffle(words_list)

# %%
print(words_list[0:10])
# base_path = "/content/data"
# Out:
# ['e04-030-04-08 ok 170 1489 1499 120 39 JJ sure\n', 'k02-102-05-03 ok 182 836 1623 69 52 PP3A he\n', 'a01-082u-01-04 ok 172 1582 1043 234 88 IN during\n', 'm01-000-07-00 ok 196 339 1998 75 107 INO of\n', 'g01-031-07-06 ok 152 1912 2038 167 59 NN booty\n', 'f07-081b-01-06 ok 168 1366 924 350 88 NN gastronomy\n', 'n03-082-04-03 ok 165 992 1414 118 135 NN boy\n', 'g06-018c-04-05 ok 182 1298 1438 96 58 ATI The\n', 'g06-011j-06-06 ok 182 1222 1785 146 95 CC and\n', 'f04-024-01-06 ok 183 1104 981 60 70 IN in\n']

# %%
# We will split the dataset into three subsets with a 90:5:5 ratio (train:validation:test)

# %%
split_idx = int(0.9*len(words_list))
train_samples = words_list[:split_idx]
test_samples = words_list[split_idx:]

val_split_idx = int(0.5 * len(test_samples))
validation_samples = test_samples[:val_split_idx]
test_samples = test_samples[val_split_idx:]

assert len(words_list) == len(train_samples) + len(validation_samples) + len(test_samples)

print(f"Total Training Samples: {len(train_samples)}")
print(f"Total validation samples: {len(validation_samples)}")
print(f"Total test samples: {len(test_samples)}")
# Out:
# Total Training Samples: 86810
# Total validation samples: 4823
# Total test samples: 4823

# %% [markdown]
# # **Data input pipeline**
#
# We start builind our data inpuit pipeline by first preparing the image paths

# %%
base_image_path = os.path.join(base_path, "words")
print(base_path)
def get_image_paths_and_labels(samples):
  paths = []
  corrected_samples = []
  for (i, file_line) in enumerate(samples):
    line_split = file_line.strip()
    line_split = line_split.split(" ")

    # Each line split willl have this format for the the corresponding image:
    # part1/part1-part2/part1-part2-part3.png
    image_name = line_split[0]
    partI = image_name.split("-")[0]
    partII = image_name.split("-")[1]
    img_path = os.path.join(
        base_image_path, partI, partI + "-" + partII, image_name + ".png"
    )
    if os.path.getsize(img_path):
      paths.append(img_path)
      corrected_samples.append(file_line.split("\n")[0])

  return paths, corrected_samples

train_img_paths, train_labels = get_image_paths_and_labels(train_samples)
validation_img_paths, validation_labels = get_image_paths_and_labels(validation_samples)
test_img_paths, test_labels = get_image_paths_and_labels(test_samples)
# Out:
# ./data

# %% [markdown]
# # **Testing Data input Pipeline**

# %%
base_image_path = os.path.join(base_path, "test_imgs")
print(base_image_path)

t_images = []
from os import listdir
from os.path import isfile, join

# onlyfiles = [f for f in listdir(base_image_path) if isfile(join(base_image_path, f))]
for f in listdir(base_image_path):
  t_images_path = os.path.join(base_image_path, f)
  t_images.append(t_images_path)

print(t_images)
# Out:
# ./data/test_imgs
# ['./data/test_imgs/line0word0.jpg', './data/test_imgs/line0word1.jpg', './data/test_imgs/line0word2.jpg', './data/test_imgs/line0word3.jpg', './data/test_imgs/line0word4.jpg', './data/test_imgs/line10word0.jpg', './data/test_imgs/line10word1.jpg', './data/test_imgs/line1word0.jpg', './data/test_imgs/line1word1.jpg', './data/test_imgs/line1word2.jpg', './data/test_imgs/line1word3.jpg', './data/test_imgs/line1word4.jpg', './data/test_imgs/line1word5.jpg', './data/test_imgs/line1word6.jpg', './data/test_imgs/line1word7.jpg', './data/test_imgs/line2word0.jpg', './data/test_imgs/line2word1.jpg', './data/test_imgs/line2word3.jpg', './data/test_imgs/line2word4.jpg', './data/test_imgs/line2word5.jpg', './data/test_imgs/line2word6.jpg', './data/test_imgs/line3word0.jpg', './data/test_imgs/line3word1.jpg', './data/test_imgs/line3word2.jpg', './data/test_imgs/line3word3.jpg', './data/test_imgs/line3word4.jpg', './data/test_imgs/line3word5.jpg', './data/test_imgs/line4word0.jpg', './data/test_imgs/line4word1.jpg', './data/test_imgs/line4word2.jpg', './data/test_imgs/line4word3.jpg', './data/test_imgs/line4word4.jpg', './data/test_imgs/line4word5.jpg', './data/test_imgs/line4word6.jpg', './data/test_imgs/line5word0.jpg', './data/test_imgs/line5word1.jpg', './data/test_imgs/line5word2.jpg', './data/test_imgs/line5word3.jpg', './data/test_imgs/line5word4.jpg', './data/test_imgs/line5word5.jpg', './data/test_imgs/line5word6.jpg', './data/test_imgs/line5word7.jpg', './data/test_imgs/line6word0.jpg', './data/test_imgs/line6word1.jpg', './data/test_imgs/line6word2.jpg', './data/test_imgs/line6word3.jpg', './data/test_imgs/line6word4.jpg', './data/test_imgs/line6word5.jpg', './data/test_imgs/line6word6.jpg', './data/test_imgs/line6word7.jpg', './data/test_imgs/line7word0.jpg', './data/test_imgs/line7word2.jpg', './data/test_imgs/line7word3.jpg', './data/test_imgs/line7word4.jpg', './data/test_imgs/line7word5.jpg', './data/test_imgs/line7word6.jpg', './data/test_imgs/line7word7.jpg', './data/test_imgs/line7word8.jpg', './data/test_imgs/line7word9.jpg', './data/test_imgs/line8word0.jpg', './data/test_imgs/line8word1.jpg', './data/test_imgs/line8word2.jpg', './data/test_imgs/line8word3.jpg', './data/test_imgs/line8word4.jpg', './data/test_imgs/line8word5.jpg', './data/test_imgs/line8word6.jpg', './data/test_imgs/line8word7.jpg', './data/test_imgs/line8word8.jpg', './data/test_imgs/line9word0.jpg', './data/test_imgs/line9word1.jpg', './data/test_imgs/line9word10.jpg', './data/test_imgs/line9word2.jpg', './data/test_imgs/line9word3.jpg', './data/test_imgs/line9word4.jpg', './data/test_imgs/line9word5.jpg', './data/test_imgs/line9word6.jpg', './data/test_imgs/line9word7.jpg', './data/test_imgs/line9word8.jpg', './data/test_imgs/line9word9.jpg', './data/test_imgs/line2word2.jpg', './data/test_imgs/line4word7.jpg', './data/test_imgs/line7word1.jpg']

# %%
t_images[0:10]
# Out:
# ['./data/test_imgs/line0word0.jpg',
#  './data/test_imgs/line0word1.jpg',
#  './data/test_imgs/line0word2.jpg',
#  './data/test_imgs/line0word3.jpg',
#  './data/test_imgs/line0word4.jpg',
#  './data/test_imgs/line10word0.jpg',
#  './data/test_imgs/line10word1.jpg',
#  './data/test_imgs/line1word0.jpg',
#  './data/test_imgs/line1word1.jpg',
#  './data/test_imgs/line1word2.jpg']

# %%
# Sorting string list with numbers

import re

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

# alist=[
#     "something1",
#     "something12",
#     "something17",
#     "something2",
#     "something25",
#     "something29"]

t_images.sort(key=natural_keys)
print(t_images)
# Out:
# ['./data/test_imgs/line0word0.jpg', './data/test_imgs/line0word1.jpg', './data/test_imgs/line0word2.jpg', './data/test_imgs/line0word3.jpg', './data/test_imgs/line0word4.jpg', './data/test_imgs/line1word0.jpg', './data/test_imgs/line1word1.jpg', './data/test_imgs/line1word2.jpg', './data/test_imgs/line1word3.jpg', './data/test_imgs/line1word4.jpg', './data/test_imgs/line1word5.jpg', './data/test_imgs/line1word6.jpg', './data/test_imgs/line1word7.jpg', './data/test_imgs/line2word0.jpg', './data/test_imgs/line2word1.jpg', './data/test_imgs/line2word2.jpg', './data/test_imgs/line2word3.jpg', './data/test_imgs/line2word4.jpg', './data/test_imgs/line2word5.jpg', './data/test_imgs/line2word6.jpg', './data/test_imgs/line3word0.jpg', './data/test_imgs/line3word1.jpg', './data/test_imgs/line3word2.jpg', './data/test_imgs/line3word3.jpg', './data/test_imgs/line3word4.jpg', './data/test_imgs/line3word5.jpg', './data/test_imgs/line4word0.jpg', './data/test_imgs/line4word1.jpg', './data/test_imgs/line4word2.jpg', './data/test_imgs/line4word3.jpg', './data/test_imgs/line4word4.jpg', './data/test_imgs/line4word5.jpg', './data/test_imgs/line4word6.jpg', './data/test_imgs/line4word7.jpg', './data/test_imgs/line5word0.jpg', './data/test_imgs/line5word1.jpg', './data/test_imgs/line5word2.jpg', './data/test_imgs/line5word3.jpg', './data/test_imgs/line5word4.jpg', './data/test_imgs/line5word5.jpg', './data/test_imgs/line5word6.jpg', './data/test_imgs/line5word7.jpg', './data/test_imgs/line6word0.jpg', './data/test_imgs/line6word1.jpg', './data/test_imgs/line6word2.jpg', './data/test_imgs/line6word3.jpg', './data/test_imgs/line6word4.jpg', './data/test_imgs/line6word5.jpg', './data/test_imgs/line6word6.jpg', './data/test_imgs/line6word7.jpg', './data/test_imgs/line7word0.jpg', './data/test_imgs/line7word1.jpg', './data/test_imgs/line7word2.jpg', './data/test_imgs/line7word3.jpg', './data/test_imgs/line7word4.jpg', './data/test_imgs/line7word5.jpg', './data/test_imgs/line7word6.jpg', './data/test_imgs/line7word7.jpg', './data/test_imgs/line7word8.jpg', './data/test_imgs/line7word9.jpg', './data/test_imgs/line8word0.jpg', './data/test_imgs/line8word1.jpg', './data/test_imgs/line8word2.jpg', './data/test_imgs/line8word3.jpg', './data/test_imgs/line8word4.jpg', './data/test_imgs/line8word5.jpg', './data/test_imgs/line8word6.jpg', './data/test_imgs/line8word7.jpg', './data/test_imgs/line8word8.jpg', './data/test_imgs/line9word0.jpg', './data/test_imgs/line9word1.jpg', './data/test_imgs/line9word2.jpg', './data/test_imgs/line9word3.jpg', './data/test_imgs/line9word4.jpg', './data/test_imgs/line9word5.jpg', './data/test_imgs/line9word6.jpg', './data/test_imgs/line9word7.jpg', './data/test_imgs/line9word8.jpg', './data/test_imgs/line9word9.jpg', './data/test_imgs/line9word10.jpg', './data/test_imgs/line10word0.jpg', './data/test_imgs/line10word1.jpg']

# %%
train_img_paths[0:10]
# Out:
# ['./data/words/e04/e04-030/e04-030-04-08.png',
#  './data/words/k02/k02-102/k02-102-05-03.png',
#  './data/words/a01/a01-082u/a01-082u-01-04.png',
#  './data/words/m01/m01-000/m01-000-07-00.png',
#  './data/words/g01/g01-031/g01-031-07-06.png',
#  './data/words/f07/f07-081b/f07-081b-01-06.png',
#  './data/words/n03/n03-082/n03-082-04-03.png',
#  './data/words/g06/g06-018c/g06-018c-04-05.png',
#  './data/words/g06/g06-011j/g06-011j-06-06.png',
#  './data/words/f04/f04-024/f04-024-01-06.png']

# %%
train_labels[0: 10]
# Out:
# ['e04-030-04-08 ok 170 1489 1499 120 39 JJ sure',
#  'k02-102-05-03 ok 182 836 1623 69 52 PP3A he',
#  'a01-082u-01-04 ok 172 1582 1043 234 88 IN during',
#  'm01-000-07-00 ok 196 339 1998 75 107 INO of',
#  'g01-031-07-06 ok 152 1912 2038 167 59 NN booty',
#  'f07-081b-01-06 ok 168 1366 924 350 88 NN gastronomy',
#  'n03-082-04-03 ok 165 992 1414 118 135 NN boy',
#  'g06-018c-04-05 ok 182 1298 1438 96 58 ATI The',
#  'g06-011j-06-06 ok 182 1222 1785 146 95 CC and',
#  'f04-024-01-06 ok 183 1104 981 60 70 IN in']

# %% [markdown]
# Then we prepare the groung-truth labels

# %%
# find maximum length and the size of the vocabulary in the training data.

train_labels_cleaned = []
characters = set()
max_len = 0

for label in train_labels:
  label = label.split(" ")[-1].strip()
  for char in label:
    characters.add(char)

  max_len = max(max_len, len(label))
  train_labels_cleaned.append(label)

print("Maximum length: ", max_len)
print("Vocab size: ", len(characters))

# Check some label samples
train_labels_cleaned[:10]
# Out:
# Maximum length:  21
# Vocab size:  78
# ['sure',
#  'he',
#  'during',
#  'of',
#  'booty',
#  'gastronomy',
#  'boy',
#  'The',
#  'and',
#  'in']

# %% [markdown]
# Now we clean the validation and the test labels as well

# %%
def clean_labels(labels):
  cleaned_labels = []
  for label in labels:
    label = label.split(" ")[-1].strip()
    cleaned_labels.append(label)
  return cleaned_labels

validation_labels_cleaned = clean_labels(validation_labels)
test_labels_cleaned = clean_labels(test_labels)

# %%
ff = list(characters)

# %%
# import pickle
# with open("/content/drive/MyDrive/Colab Notebooks/OCR_course/characters", "wb") as fp:   #Pickling
#     pickle.dump(ff, fp)

# %%
import pickle
with open("./characters", "rb") as fp:   # Unpickling
    b = pickle.load(fp)
    print(b)
# Out:
# ['L', 'E', '"', '0', '2', 's', 'l', 'w', 'p', 'P', 'H', '/', 'O', 'V', 'f', '!', 'X', 'v', 'M', ':', 'N', '4', '3', "'", 'F', 'J', '(', 'K', '+', 'o', '#', 'I', 'r', '9', ',', '&', '8', 'B', '*', 'Q', 'g', '.', 'W', 'j', 'q', 'm', 'c', '5', ';', '7', 'U', 'h', 'u', 'a', ')', 'R', 'i', 'C', 'z', 'n', '-', 'Y', 'D', 'x', 'd', 'S', 'y', 'Z', 'e', 'k', 'G', '?', 'T', 'A', '6', 't', '1', 'b']

# %% [markdown]
# **Building the character vocabulary**

# %%
AUTOTUNE = tf.data.AUTOTUNE

# Maping characaters to integers
char_to_num = StringLookup(vocabulary=b, mask_token=None)

#Maping integers back to original characters
num_to_chars = StringLookup(vocabulary=char_to_num.get_vocabulary(), mask_token=None, invert=True)

# %% [markdown]
# - Resizing images without distortion
#
# Instead of square images, many OCR models work with rectangular images. This will become clearer in a moment when we will visualize a few
# ‘samples from the dataset. While aspect-unaware resizing square images does not introduce a significant amount of distortion this is not the
# case for rectangular images. But resizing images to a uniform size is a requirement for mini-batching. So we need to perform our resizing such
# that the following criteria are met:
#
# + Aspect ratio is preserved.
#
# + Content of the images is not affected.

# %%
def distortion_free_resize(image, img_size):
  w, h = img_size
  image = tf.image.resize(image, size=(h, w), preserve_aspect_ratio=True)

  # Check tha amount of padding needed to be done.
  pad_height = h - tf.shape(image)[0]
  pad_width = w - tf.shape(image)[1]

  # only necessary if you want to do same amount of padding on both sides.
  if pad_height % 2 != 0:
    height = pad_height // 2
    pad_height_top = height +1
    pad_height_bottom = height
  else:
    pad_height_top = pad_height_bottom = pad_height // 2

  if pad_width % 2 != 0:
    width = pad_width // 2
    pad_width_left = width + 1
    pad_width_right = width
  else:
    pad_width_left = pad_width_right = pad_width // 2

  image = tf.pad(
      image, paddings=[
          [pad_height_top, pad_height_bottom],
          [pad_width_left, pad_width_right],
          [0, 0],
      ],
  )
  image = tf.transpose(image, perm=[1,0,2])
  image = tf.image.flip_left_right(image)
  return image

# %% [markdown]
# # if we just go witht the plain resizing then the images would look like so:
#
# # putting the utilities together

# %%
batch_size = 64
padding_token = 99
image_width = 128
image_height = 32

def preprocess_image(image_path, img_size=(image_width, image_height)):
  image = tf.io.read_file(image_path)
  image = tf.image.decode_png(image, 1)
  image = distortion_free_resize(image, img_size)
  image = tf.cast(image, tf.float32) / 255.0
  return image

def vectorize_label(label):
  label = char_to_num(tf.strings.unicode_split(label, input_encoding="UTF-8"))
  length = tf.shape(label)[0]
  pad_amount = max_len - length
  label = tf.pad(label, paddings=[[0, pad_amount]], constant_values=padding_token)
  return label

 
def process_images_labels(image_path, label):
  image = preprocess_image(image_path)
  label = vectorize_label(label)
  return {"image": image, "label": label}
  
def prepare_dataset(image_paths, labels):
  dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels)).map(
    process_images_labels, num_parallel_calls=AUTOTUNE
  )

  return dataset.batch(batch_size).cache().prefetch(AUTOTUNE)

# %% [markdown]
# Prepare tf.data.Dataset objects

# %%
train_ds = prepare_dataset(train_img_paths, train_labels_cleaned)
validation_ds = prepare_dataset(validation_img_paths, validation_labels_cleaned)
test_ds = prepare_dataset(test_img_paths, test_labels_cleaned)

# %% [markdown]
# ## Preparing new inference/testing images

# %%
# Testing inference images
batch_size = 64
padding_token = 99
image_width = 128
image_height = 32

def preprocess_image(image_path, img_size=(image_width, image_height)):
  image = tf.io.read_file(image_path)
  image = tf.image.decode_png(image, 1)
  image = distortion_free_resize(image, img_size)
  image = tf.cast(image, tf.float32) / 255.0
  return image

def process_images_2(image_path):
  image = preprocess_image(image_path)
  # label = vectorize_label(label)
  return {"image": image}
  
def prepare_test_images(image_paths):
  dataset = tf.data.Dataset.from_tensor_slices((image_paths)).map(
    process_images_2, num_parallel_calls=AUTOTUNE
  )

  # return dataset
  return dataset.batch(batch_size).cache().prefetch(AUTOTUNE)

inf_images = prepare_test_images(t_images)

# %% [markdown]
# ## Visualize new test images

# %%
# Visualize test images 

from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

for data in inf_images.take(1):
  images = data["image"]
  # imm = images.reshape(images.shape[0], (images.shape[1]*images.shape[2]))
  # imm = imm.transpose()
  # print(imm.shape)
  _, ax = plt.subplots(4, 4, figsize=(15, 8))

  # ss = plt.imshow(imm, cmap="gray")
  # plt.show()
  for i in range(16): 
    img = images[i]
    # print(img.shape)
    img = tf.image.flip_left_right(img)
    img = tf.transpose(img, perm=[1, 0, 2])
    img = (img * 255.0).numpy().clip(0, 255).astype(np.uint8)
    img = img[:, :, 0]

    # Gather indices where Label!= padding token

    ax[i // 4, i % 4].imshow(img, cmap="gray")
    

  plt.show()
# Out:
# 2024-05-04 02:20:37.722825: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [82]
# 	 [[{{node Placeholder/_0}}]]
# 2024-05-04 02:20:37.723241: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [82]
# 	 [[{{node Placeholder/_0}}]]
# 2024-05-04 02:20:37.951346: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# Visualize few samples

# %%
for data in train_ds.take(1):
  images, labels = data["image"], data["label"]
  _, ax = plt.subplots(4, 4, figsize=(15, 8))

  for i in range(16): 
    img = images[i]
    # print(img.shape)
    img = tf.image.flip_left_right(img)
    img = tf.transpose(img, perm=[1, 0, 2])
    img = (img * 255.0).numpy().clip(0, 255).astype(np.uint8)
    img = img[:, :, 0]

    # Gather indices where Label!= padding token
    label = labels[i]
    indices = tf.gather(label, tf.where(tf.math.not_equal(label, padding_token)))
    # Convert to string.
    label = tf.strings.reduce_join(num_to_chars(indices))
    label = label.numpy().decode("utf-8")

    ax[i // 4, i % 4].imshow(img, cmap="gray")
    ax[i // 4, i % 4].set_title(label)
    ax[i // 4, i % 4].axis("off")

  plt.show()
# Out:
# 2024-05-04 02:20:53.934613: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype resource
# 	 [[{{node Placeholder/_3}}]]
# 2024-05-04 02:20:53.935448: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [86808]
# 	 [[{{node Placeholder/_0}}]]
# 2024-05-04 02:20:54.212525: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# # **Model**
#
# Model uses CTC loss as an endpoint layer.

# %%
class CTCLayer(keras.layers.Layer):

  def __init__(self, name=None):
    super().__init__(name=name)
    self.loss_fn = keras.backend.ctc_batch_cost

  def call(self, y_true, y_pred):
    batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
    input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
    label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")

    input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
    label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")
    loss = self.loss_fn(y_true, y_pred, input_length, label_length)
    self.add_loss(loss)

    # At test time, just return the computed predictions.
    return y_pred

def build_model():
  input_img = keras.Input(shape=(image_width, image_height, 1), name="image")
  labels = keras.layers.Input(name="label", shape=(None,))

  # first conv block
  x = keras.layers.Conv2D(
      32, (3,3), activation = "relu",
      kernel_initializer="he_normal",
      padding="same",
      name="Conv1"
  )(input_img)
  x = keras.layers.MaxPooling2D((2,2), name="pool1")(x)

  # Second conv block
  x = keras.layers.Conv2D(
      64, (3,3), activation = "relu", kernel_initializer="he_normal",
      padding="same",
      name="Conv2"
  )(x)
  x = keras.layers.MaxPooling2D((2,2), name="pool2")(x)

  # We have two maxpool layers with pool size and strides 2
  # Hence downsampled feature maps are 4x smaller the number of filters in the last layer is 64, 
  # Reshape accordingly before passing the output to the RNN part of the model.
  
  new_shape = ((image_width // 4), (image_height // 4) * 64)
  x = keras.layers.Reshape(target_shape=new_shape, name="reshape")(x)
  x = keras.layers.Dense(64, activation="relu", name="dense1")(x)
  x = keras.layers.Dropout(0.2)(x)

  # RNN
  x = keras.layers.Bidirectional(
      keras.layers.LSTM(128, return_sequences=True, dropout=0.25)
  )(x)
  x = keras.layers.Bidirectional(
    keras.layers.LSTM(64, return_sequences=True, dropout=0.25)
  )(x)
  # +2 is to account for the two special tokens introduced by the CTC loss.
  # The recommendation comes here: https://git.10/J0eXP.
  x = keras.layers.Dense(
    len(char_to_num.get_vocabulary()) + 2, activation="softmax", name="dense2"
  )(x)
  # Add CTC layer for calculating CTC Loss at each step.
  output = CTCLayer(name="ctc_loss")(labels, x)

  # Define the model.
  model = keras.models.Model(
      inputs=[input_img, labels], outputs=output, name="handwriting_recognizer"
  )
  
  # optimizer
  opt = keras.optimizers.Adam()
  # Compile the model and return
  model.compile(optimizer=opt)
  return model

# Get the model
model = build_model()
model.summary()
# Out:
# 2024-05-04 02:21:14.366110: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 02:21:14.367377: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 02:21:14.368419: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-04 02:21:14.505339: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-04 02:21:14.551733: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 02:21:14.552895: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 02:21:14.553996: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-04 02:21:14.771117: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 02:21:14.772516: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 02:21:14.773766: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-04 02:21:14.914276: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-04 02:21:14.963278: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 02:21:14.964552: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 02:21:14.965747: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Model: "handwriting_recognizer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image (InputLayer)             [(None, 128, 32, 1)  0           []
#                                 ]
#
#  Conv1 (Conv2D)                 (None, 128, 32, 32)  320         ['image[0][0]']
#
#  pool1 (MaxPooling2D)           (None, 64, 16, 32)   0           ['Conv1[0][0]']
#
#  Conv2 (Conv2D)                 (None, 64, 16, 64)   18496       ['pool1[0][0]']
#
#  pool2 (MaxPooling2D)           (None, 32, 8, 64)    0           ['Conv2[0][0]']
#
#  reshape (Reshape)              (None, 32, 512)      0           ['pool2[0][0]']
#
#  dense1 (Dense)                 (None, 32, 64)       32832       ['reshape[0][0]']
#
#  dropout (Dropout)              (None, 32, 64)       0           ['dense1[0][0]']
#
#  bidirectional (Bidirectional)  (None, 32, 256)      197632      ['dropout[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 32, 128)     164352      ['bidirectional[0][0]']
#  )
#
#  label (InputLayer)             [(None, None)]       0           []
#
#  dense2 (Dense)                 (None, 32, 81)       10449       ['bidirectional_1[0][0]']
#
#  ctc_loss (CTCLayer)            (None, 32, 81)       0           ['label[0][0]',
#                                                                   'dense2[0][0]']
#
# ==================================================================================================
# Total params: 424,081
# Trainable params: 424,081
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2024-05-04 02:21:15.109158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'ctc_loss/scan/while/Fill/ctc_loss/stack_1' with dtype int32 and shape [1]
# 	 [[{{node ctc_loss/scan/while/Fill/ctc_loss/stack_1}}]]
# 2024-05-04 02:21:15.109255: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'ctc_loss/scan/while/Fill/ctc_loss/stack_1' with dtype int32 and shape [1]
# 	 [[{{node ctc_loss/scan/while/Fill/ctc_loss/stack_1}}]]

# %% [markdown]
# # **Evaluation Metrix**

# %%
# Edit Distance is the most widely used metric for evaluating OCR models. In this section, we will implement it and use it as a callback to monitor
# ‘our model.

# We first segregate the validation images and their labels for convenience.

validation_images = []
validation_labels = []

for batch in validation_ds:
  validation_images.append(batch["image"])
  validation_labels.append(batch["label"])
# Out:
# 2024-05-04 02:21:35.469614: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int64
# 	 [[{{node Placeholder/_4}}]]
# 2024-05-04 02:21:35.470170: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype resource
# 	 [[{{node Placeholder/_3}}]]

# %% [markdown]
# Now we create a callback to monitor the edit distance

# %%
def calculate_edit_distance(labels, predictions):
  # Get a single batch and convert its labels to sparse tensors.
  sparse_labels = tf.cast(tf.sparse.from_dense(labels), dtype=tf.int64)

  # Make predictions and convert them to sparse tensors.
  input_len = np.ones(predictions.shape[0]) * predictions.shape[1]
  predictions_decoded = keras.backend.ctc_decode(
    predictions, input_length=input_len, greedy=True
  )[0][0][:, :max_len]
  sparse_predictions = tf.cast(
    tf.sparse.from_dense(predictions_decoded), dtype=tf.int64
  )

  # Compute individual edit distances and average them out.
  edit_distances = tf.edit_distance(
    sparse_predictions, sparse_labels, normalize=False
  )
  return tf.reduce_mean(edit_distances)

class EditDistanceCallback(keras.callbacks.Callback):
  def __init__(self, pred_model):
    super().__init__()
    self.prediction_model = pred_model
  def on_epoch_end(self, epoch, logs = None):
    edit_distances = []

    for i in range(len(validation_images)):
      labels = validation_labels[i]
      predictions = self.prediction_model.predict(validation_images[i])
      edit_distances.append(calculate_edit_distance(labels, predictions).numpy())
    print(f"Mean eidt distance for each {epoch + 1}: {np.mean(edit_distances): .4f}")

# %% [markdown]
# # **Training**

# %%
# Now we are ready to kick off model training,

epochs = 50 # To get good results this should be at least 50.

model = build_model()
prediction_model = keras.models.Model(
  model.get_layer(name="image").input, model.get_layer(name="dense2").output
)
edit_distance_callback = EditDistanceCallback(prediction_model)

# Train the model.
history = model.fit(
  train_ds,
  validation_data=validation_ds,
  epochs=epochs,
  callbacks=[edit_distance_callback],
)
# Out:
# 2024-05-04 02:22:20.316424: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 02:22:20.317879: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 02:22:20.318992: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-04 02:22:20.458712: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-04 02:22:20.504908: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 02:22:20.506033: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 02:22:20.507108: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-04 02:22:20.719518: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 02:22:20.720965: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 02:22:20.722141: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-04 02:22:20.892360: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-04 02:22:20.957317: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 02:22:20.958956: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 02:22:20.960153: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-04 02:22:21.044303: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'ctc_loss/scan/while/Fill/ctc_loss/stack_1' with dtype int32 and shape [1]
# 	 [[{{node ctc_loss/scan/while/Fill/ctc_loss/stack_1}}]]
# 2024-05-04 02:22:21.044398: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'ctc_loss/scan/while/Fill/ctc_loss/stack_1' with dtype int32 and shape [1]
# 	 [[{{node ctc_loss/scan/while/Fill/ctc_loss/stack_1}}]]
# 2024-05-04 02:22:21.130687: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [86808]
# 	 [[{{node Placeholder/_0}}]]
# 2024-05-04 02:22:21.130991: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dt
[==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 102ms/step
# Mean eidt distance for each 49:  17.3304
# 1357/1357 [==============================] - 730s 538ms/step - loss: 1.6024 - val_loss: 1.7163
# Epoch 50/50
# 2/2 [==============================] - 0s 157ms/step - loss: 1.
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 120ms/step
# 2/2 [==============================] - 0s 121ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 133ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 127ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 128ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 128ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 128ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 132ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 162ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 131ms/step
# 2/2 [==============================] - 0s 161ms/step
# 2/2 [==============================] - 0s 159ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 120ms/step
# 2/2 [==============================] - 0s 133ms/step
# 2/2 [==============================] - 0s 104ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 161ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 131ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 159ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 157ms/step
# 2/2 [==============================] - 0s 133ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 91ms/step
# Mean eidt distance for each 50:  17.3191
# 1357/1357 [==============================] - 753s 555ms/step - loss: 1.5945 - val_loss: 1.6926

# %%
# Saving thje model

model.save_weights('./new_model/ocr_model_v4.h5')
prediction_model.save_weights('./new_model/ocr_model_v5.h5')

# #Below is working saved models
# model.save("./new_model/ocr_model_v8.h5")
 prediction_model.save("./new_model/ocr_model_50_epoch.h5")

# %%
# model.save("./new_model/ocr_model_v8.h5")
# prediction_model.save("./new_model/ocr_model_50_epoch.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# # **Inferences**

# %%
# A utility function to decode the output of the network
def decode_batch_predictions(pred):
    input_len = np.ones(pred.shape[0]) * pred.shape[1]
    # Use greedy search. For complex tasks, you can use beam search.
    results = keras.backend.ctc_decode(pred, input_length=input_len, greedy=True)[0][0][
        :, :max_len
    ]

    # Iterate over the results and get back the text.
    output_text = []

    for res in results:
      res = tf.gather(res, tf.where(tf.math.not_equal(res, -1)))
      res = tf.strings.reduce_join(num_to_chars(res)).numpy().decode("utf-8")
      output_text.append(res)

    return output_text


# Let's check results on sone test samples.
for batch in test_ds.take(1):
    batch_images = batch["image"]
    print(batch_images.shape)

    _, ax = plt.subplots(4, 4, figsize=(15, 8))

    preds = prediction_model.predict(batch_images)
    pred_texts = decode_batch_predictions(preds)

    for i in range(16):
      img = batch_images[i]
      img = tf.image.flip_left_right(img)
      img = tf.transpose(img, perm=[1, 0, 2])
      img = (img * 255.0).numpy().clip(0, 255).astype(np.uint8)
      img = img[:, :, 0]

      title = f"Prediction: {pred_texts[i]}"
      ax[i // 4, i % 4].imshow(img, cmap = "gray")
      ax[i // 4, i % 4].set_title(title)
      ax[i // 4, i % 4].axis("off")

    plt.show()
# Out:
# 2024-05-04 19:00:48.290477: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype resource
# 	 [[{{node Placeholder/_3}}]]
# 2024-05-04 19:00:48.290889: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype resource
# 	 [[{{node Placeholder/_3}}]]
# (64, 128, 32, 1)
# 2024-05-04 19:00:48.542719: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2/2 [==============================] - 0s 122ms/step

# %%
# THE END

# %% [markdown]
# # Inference on New set of images

# %%
custom_objects = {"CTCLayer": CTCLayer}

# %%
 reconstructed_model = keras.models.load_model("./ocr_model_50_epoch.h5", custom_objects=custom_objects)
#reconstructed_model = keras.models.load_model("./new_model/ocr_model_v5.h5", custom_objects=custom_objects)
# Out:
# 2024-05-04 19:03:17.229713: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 19:03:17.230827: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 19:03:17.231972: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-04 19:03:17.376970: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-04 19:03:17.423951: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 19:03:17.425098: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 19:03:17.426130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-04 19:03:17.632233: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 19:03:17.633589: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 19:03:17.634708: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-04 19:03:17.777254: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-04 19:03:17.826071: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 19:03:17.827320: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 19:03:17.828391: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
prediction_model = keras.models.Model(
  reconstructed_model.get_layer(name="image").input, reconstructed_model.get_layer(name="dense2").output
)

# %%
# Inference on New set of images
pred_test_text = []

# A utility function to decode the output of the network
def decode_batch_predictions(pred):
    input_len = np.ones(pred.shape[0]) * pred.shape[1]
    # Use greedy search. For complex tasks, you can use beam search.
    results = keras.backend.ctc_decode(pred, input_length=input_len, greedy=True)[0][0][
        :, :max_len
    ]

    # Iterate over the results and get back the text.
    output_text = []

    for res in results:
      res = tf.gather(res, tf.where(tf.math.not_equal(res, -1)))
      res = tf.strings.reduce_join(num_to_chars(res)).numpy().decode("utf-8")
      output_text.append(res)

    return output_text


# Let's check results on sone test samples.
for batch in inf_images.take(3):
    batch_images = batch["image"]
    # batch_images= tf.expand_dims(batch_images, axis=0)
    print(batch_images.shape)
    # print(batch_images.shape)

    _, ax = plt.subplots(4, 4, figsize=(15, 8))

    preds = prediction_model.predict(batch_images)
    pred_texts = decode_batch_predictions(preds)
    pred_test_text.append(pred_texts)

    for i in range(16):
      img = batch_images[i]
      img = tf.image.flip_left_right(img)
      img = tf.transpose(img, perm=[1, 0, 2])
      img = (img * 255.0).numpy().clip(0, 255).astype(np.uint8)
      img = img[:, :, 0]

      title = f"Prediction: {pred_texts[i]}"
      ax[i // 4, i % 4].imshow(img, cmap = "gray")
      ax[i // 4, i % 4].set_title(title)
      ax[i // 4, i % 4].axis("off")

    plt.show()
# Out:
# 2024-05-04 18:53:37.714537: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [82]
# 	 [[{{node Placeholder/_0}}]]
# 2024-05-04 18:53:37.715139: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [82]
# 	 [[{{node Placeholder/_0}}]]
# (64, 128, 32, 1)
# 2024-05-04 18:53:40.501505: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 18:53:40.504245: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 18:53:40.506236: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-04 18:53:40.740821: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-04 18:53:40.828014: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 18:53:40.830449: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 18:53:40.832563: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-04 18:53:41.143463: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 18:53:41.145908: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 18:53:41.147827: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-04 18:53:41.359518: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-04 18:53:41.457999: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 18:53:41.461261: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 18:53:41.463644: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2/2 [==============================] - 2s 91ms/step
# (18, 128, 32, 1)
# 2024-05-04 18:53:43.569012: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 18:53:43.571229: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 18:53:43.572948: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-04 18:53:43.743183: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-04 18:53:43.815432: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 18:53:43.818285: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 18:53:43.819737: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-04 18:53:44.066193: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 18:53:44.067800: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 18:53:44.069482: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-04 18:53:44.245442: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2024-05-04 18:53:44.312373: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-04 18:53:44.314103: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-04 18:53:44.315868: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 1/1 [==============================] - 2s 2s/step

# %%
# for batch in inf_images:
#     batch_images = batch["image"]
#     # batch_images= tf.expand_dims(batch_images, axis=0)
#     print(batch_images.shape)
# Out:
# (64, 128, 32, 1)
# (18, 128, 32, 1)

# %%
flat_list = [item for sublist in pred_test_text for item in sublist]
print(flat_list)
# Out:
# ['The', 'doorman', 'turned', 'ws', 'attention', "'o", 'the', 'nesxt', 'red', 'ened', 'emerger', 'from', 'the', 'dark', 'and', 'we', 'went', 'an', 'tosether', 'to', 'the', 'station', 'the', 'children', 'silent', 'because', 'of', 'the', 'cruelty', 'of', 'the', 'world', 'Finally', 'Catherine', 'sand', 'her', 'eyes', 'wet', 'agan', 'think', 'its', 'all', 'abslutely', 'beasthyy', 'and', 'I', 'can', "'f", 'bear', 'tothink', 'about', 'it', 'And', 'D1', 'hikip', 'sand', 'But', 'we', 'we', 'aot', 'to', 'think', 'about', 'it', 'dai', 'It', 'non', 'see', 'because', 'if', 'we', 'donit', 'itll', 'just', 'ber', 'on', 'and', 'an', 'don', 'I', 'non', 'see']

# %%
sentence = ' '.join(flat_list)
print(sentence)
# Out:
# The doorman turned ws attention 'o the nesxt red ened emerger from the dark and we went an tosether to the station the children silent because of the cruelty of the world Finally Catherine sand her eyes wet agan think its all abslutely beasthyy and I can 'f bear tothink about it And D1 hikip sand But we we aot to think about it dai It non see because if we donit itll just ber on and an don I non see
